# %% [markdown]
# # Семинар 2

# %% [markdown]
# ## Условия

# %% [markdown]
# Оператор `if` позволяет нам задавать условия, при выполнении которых часть кода будет выполняться. У этого оператора такой синтаксис:
#
# ```
# if a > 0:
#     print("Это правда, переменная a больше нуля.")
#     print("А больше и сказать-то тут нечего.")
# print("Программа продолжается.")
# ```
#
# После оператора `if` находится некоторое логическое условие типа `bool` (например, `a > 0` проверяет, верно ли, что переменная `a` больше нуля). Если это условие верно, то программа перейдёт к выполнению действий, написанных на строчках с отступом (например, выведет на экран какой-то текст). Если условие неверно, то программа сразу перейдёт к тому, что написано ниже строчек с отступом.
#
# **Внимание**! После условия обязательно должно стоять двоеточие, а строчки кода, которые будут выполняться при выполнении условия, обязательно должны быть написаны с отступом. Отступ должен состоять из некоторого числа пробелов. Точное число пробелов не важно, главное — чтобы оно было одинаковым на протяжении всей программы. Однако обычно программисты ставят **отступ из четырёх пробелов**, и вам рекомендуется делать так же. Такой отступ можно легко напечатать с помощью клавиши `Tab`.

# %% [markdown]
# В примере ниже программа смотрит на каждое условие отдельно, и если оно выполняется, выводит на экран соответствующие строчки. В конце выводится имя — это происходит независимо от всех заданных выше условий, так как вывод имени записан без отступов:

# %%
name = "Элоиза"
year = 1988

print(f"Год рождения: {year}.")

if year < 2000:
    print("Старше 2000 года рождения.")
if year < 1990:
    print("Старше 1990 года рождения.")
if year < 1980:
    print("Старше 1980 года рождения.")
print(f"Имя: {name}.")
# Out:
# Год рождения: 1988.
# Старше 2000 года рождения.
# Старше 1990 года рождения.
# Имя: Элоиза.

# %% [markdown]
# Ещё несколько операторов позволяют более гибко работать с условиями. Оператор `else` даёт возможность добавить ещё один блок кода, который будет, наоборот, выполняться только в том случае, если условие в `if` не выполняется. Буквально, программа говорит: «ЕСЛИ (условие), ТОГДА (действия), А_ИНАЧЕ (альтернативные действия)».

# %%
year = 1988

print(f"Год рождения: {year}.")

if year < 2000:
    print("Старше 2000 года рождения.")
else:
    print("Человек 2000 года рождения или младше.")
# Out:
# Год рождения: 1988.
# Старше 2000 года рождения.

# %%
year = 2003

print(f"Год рождения: {year}.")

if year < 2000:
    print("Старше 2000 года рождения.")
else:
    print("Человек 2000 года рождения или младше.")
# Out:
# Год рождения: 2003.
# Человек 2000 года рождения или младше.

# %% [markdown]
# То же самое в теории можно записать вот так (только с `else` проще):

# %%
print(f"Год рождения: {year}.")

if year < 2000:
    print("Старше 2000 года рождения.")
if year >= 2000:
    print("Человек 2000 года рождения или младше.")
# Out:
# Год рождения: 2003.
# Человек 2000 года рождения или младше.

# %% [markdown]
# Оператор `elif` позволяет ввести дополнительные альтернативные условия. Их может быть одно или несколько:

# %%
year = 2050

print(f"Год рождения: {year}.")

if year > 2025:
    print("Такой человек ещё не родился.")
elif year > 2000:
    print("Этот человек — молодой.")
elif year < 1935:
    print("Этот человек — пожилой.")
# Out:
# Год рождения: 2050.
# Такой человек ещё не родился.

# %% [markdown]
# В чём отличие от простого перечисления разных условий с `if`? Название `elif` — это буквально сокращение от `else` и `if`. Это значит, что условие в `elif` будет проверяться, только если условие `if` не выполнилось. А вот если мы запишем несколько условий с помощью обычного `if`, то несколько условий могут выполниться одно за другим. Перепишем ячейку выше с помощью простых `if`’ов, и увидим, что теперь вывелось больше одной надписи. Так вышло, потому что заданный год удовлетворяет и первому (`2050 > 2025`), и второму (`2050 > 2000`) условиям:

# %%
year = 2050

print(f"Год рождения: {year}.")

if year > 2025:
    print("Такой человек ещё не родился.")
if year > 2000:
    print("Этот человек — молодой.")
if year < 1935:
    print("Этот человек — пожилой.")
# Out:
# Год рождения: 2050.
# Такой человек ещё не родился.
# Этот человек — молодой.

# %% [markdown]
# Все три оператора можно комбинировать. Они могут образовывать цепочки, в которых может быть только один `if` (в начале, обязательно) и один `else` (в конце, необязательно), а также сколько угодно `elif` (в середине, необязательно):

# %%
postuplenie_year = 2014     # год поступления студентки
current_year = 2025         # текущий год

print(f"Год поступления в Вышку: {postuplenie_year}.")

if postuplenie_year > current_year:
    print("Эта студентка ещё не поступила.")
elif postuplenie_year == current_year - 5:
    print("Эта студентка только что выпустилась.")
elif postuplenie_year < current_year - 5:
    print("Эта студентка выпустилась уже давно.")
else:
    print(f"Эта студентка на {current_year - postuplenie_year} курсе.")
# Out:
# Год поступления в Вышку: 2014.
# Эта студентка выпустилась уже давно.

# %% [markdown]
# Условия можно усложнить, вложив одно в другое:

# %%
food = "печенье"
drink = "молоко"

print(f"Нам предлагают еду «{food}» с напитком «{drink}».")

if food == "печенье":
    print("Вкусно. Надо есть.")
elif food == "кольраби":
    print("Непонятно что это такое. Не хочется.")
elif food == "апельсины":
    print("Аллергия. Не надо это есть.")
    
elif food == "огурцы":
    if drink == "молоко":
        print("Аллергии нет, но лучше не пробовать.")
    else:
        print("Надо брать! хрум. хрум хрум")
# Out:
# Нам предлагают еду «печенье» с напитком «молоко».
# Вкусно. Надо есть.

# %% [markdown]
# ____

# %% [markdown]
# Для сравнения объектов между собой мы можем использовать шесть математических операторов:
# - `<` (меньше)
# - `>` (больше)
# - `<=` (меньше или равно)
# - `>=` (больше или равно)
# - `==` (равно)
# - `!=` (не равно)

# %% [markdown]
# Эти операторы можно применять не только к числам, но и к строкам. Например, можно узнать, равна ли одна строка другой:

# %%
print("break" + "fast" == "breakfast")
print("break" + "slow" == "breakfast")
print("break" + "slow" != "breakfast")
# Out:
# True
# False
# True

# %% [markdown]
# Можно также сравнивать строки между собой операторами «больше» или «меньше», но это даёт не самый очевидный результат (например, можно было бы предположить, что при сравнении питон будет выяснять, какая строка длиннее — но это не так). Когда-нибудь мы обсудим, что именно делает сравнение строк между собой, а пока что, если очень хочется, можете почитать об этом [вот здесь](https://www.geeksforgeeks.org/python/string-comparison-in-python/).

# %% [markdown]
# В питоне есть также оператор сравнения **`in`**, который можно применять к строкам, но нельзя к числам. Этот оператор выясняет, верно ли, что одна строка вложена в другую. Например, с его помощью можно выяснить, входит ли какой-то символ в длинную строку:

# %%
print("ъ" in "объегорить")
print("ъ" in "папье-маше")
# Out:
# True
# False

# %% [markdown]
# В качестве первой строки может выступать не только первая буква, но и более крупная строка:

# %%
print("ма" in "мамочка")
print("мам" in "мамочка")
print("мама" in "мамочка")
# Out:
# True
# True
# False

# %% [markdown]
# _______
#
# Для условий также есть специальные логические операторы `and` («и»), `or` («или»), `not` («не»).
#
# Оператор `and` позволяет соединить несколько условий в одно большое. В таком случае действия будут выполняться, только если все эти условия будут выполняться:

# %%
name = "АРДАШИР"

print("Имя:", name)

if name[0] == "А" and name[-1] == "Н":
    print("Первая буква — А, а последняя — Н. Это правда.")
else:
    print("Первая буква — А, а последняя — Н? Вовсе нет!")
# Out:
# Имя: АРДАШИР
# Первая буква — А, а последняя — Н? Вовсе нет!

# %%
name = "АРТАБАН"

print("Имя:", name)

if name[0] == "А" and name[-1] == "Н":
    print("Первая буква — А, а последняя — Н. Это правда.")
else:
    print("Первая буква — А, а последняя — Н? Вовсе нет!")
# Out:
# Имя: АРТАБАН
# Первая буква — А, а последняя — Н. Это правда.

# %% [markdown]
# Если склеить условия оператором `or`, то действия ниже будут выполняться, если хотя бы одно из условий выполняется:

# %%
name = "АРДАШИР"

print("Имя:", name)

if name[0] == "А" or name[-1] == "Н":
    print("Может, первая буква — А, а может, последняя — Н. Или и то, и то.")
else:
    print("Ни первая буква — не А, ни последняя — не Н!")
# Out:
# Имя: АРДАШИР
# Может, первая буква — А, а может, последняя — Н. Или и то, и то.

# %%
name = "КСЕРКС"

print("Имя:", name)

if name[0] == "А" or name[-1] == "Н":
    print("Может, первая буква — А, а может, последняя — Н. Или и то, и то.")
else:
    print("Ни первая буква — не А, ни последняя — не Н!")
# Out:
# Имя: КСЕРКС
# Ни первая буква — не А, ни последняя — не Н!

# %% [markdown]
# С помощью `not` условие можно отрицать. Например, если мы хотим выполнить какое-то действие только тогда, когда некоторое условие неверно:

# %%
name = "КСЕРКС"

print("Имя:", name)

if not name[0] == "А":
    print("Ты думал, что первая буква — А? Нет, друг, ты неправ.")
# Out:
# Имя: КСЕРКС
# Ты думал, что первая буква — А? Нет, друг, ты неправ.

# %%
name = "АРТАКСЕРКС"

print("Имя:", name)

if not name[0] == "А":
    print("Ты думал, что первая буква — А? Нет, друг, ты неправ.")
# Out:
# Имя: АРТАКСЕРКС

# %% [markdown]
# **Внимание**! Если мы соединяем несколько условий с помощью `and` или `or` и добавляем `not` к первому условию, то под отрицание попадёт только первое условие. Чтобы распространить `not` на всю комбинацию условий, надо взять эту комбинацию в скобки:

# %%
name = "АРТАКСЕРКС"

print("Имя:", name)

if not name[0] == "А" and name[-1] == "Н":
    print("Если вы видите это сообщение, это значит, что выполняются два условия: (1) первая буква — НЕ буква «А», (2) последняя буква — буква «Н».")
# Out:
# Имя: АРТАКСЕРКС

# %%
name = "АРТАКСЕРКС"

print("Имя:", name)

if not (name[0] == "А" and name[-1] == "Н"):
    print("Оба этих условия НЕ выполняются: (1) первая буква — буква «А», (2) последняя буква — буква «Н».")
    print("Иначе говоря: (1) первая буква — НЕ буква «А», а (2) последняя буква — НЕ буква «Н».")
# Out:
# Имя: АРТАКСЕРКС
# Оба этих условия НЕ выполняются: (1) первая буква — буква «А», (2) последняя буква — буква «Н».
# Иначе говоря: (1) первая буква — НЕ буква «А», а (2) последняя буква — НЕ буква «Н».

# %% [markdown]
# ## Задачи

# %% [markdown]
# ### Редупликация в ниуэ

# %% [markdown]
# В языке ниуэ (один из полинезийских языков) для выражения множественного числа подлежащего в глаголах используется **редупликация** первого слога. Это значит, что чтобы образовать форму множественного числа, ниуэан:ки дублируют первый слог глагола. Например, форма ед. ч. глагола ‘идти следом’ звучит как *mui*, а форма мн. ч. — *mumui*. При этом слоговая структура ниуэанского языка очень простая: все возможные слоги строятся либо по схеме Согласный+Гласный, либо просто Гласный (без начального согласного). Таким образом, если первый слог состоит из одного гласного, дублируется только гласный: *ala* → *aala* ‘проснуться’.
#
# Напишите программу, которая будет запрашивать у пользователя (с помощью функции `input()`) форму единственного числа и печатать форму множественного числа. Например, если пользователь вводит строку `"ala"`, программе нужно вывести `"aala"`. Условимся, что пользователь добрый и будет подавать в программу только нормальные ниуэанские глаголы.
# Для простоты вам заранее дана строка `"aeiou"`, в которой содержатся все существующие в ниуэанском языке гласные — она поможет вам при решении.
#
# Вот ещё несколько ниуэанских глаголов, на которых вы можете протестировать своё решение:
#
# - *mole* → *momole* ‘уйти’
# - *tuna* → *tutuna* ‘сидеть без дела’
# - *nono* → *nonono* ‘замолчать’
# - *hoko* → *hohoko* ‘добраться, прибыть’
# - *ofo* → *oofo* ‘быть удивлённ:ой’
#
# *Подсказка*. Для решения вам пригодится оператор `in`.

# %%
vowels = "aeiou"

# ваше решение
