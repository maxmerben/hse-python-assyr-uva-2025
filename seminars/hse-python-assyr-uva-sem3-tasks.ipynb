# %% [markdown]
# # Дополнительные задачи №3

# %% [markdown]
# ### Задача 3.1. Найти все гласные (сиквел)

# %% [markdown]
# **Внимание**: При решении этой задачи очень желательно решить сначала задачу «Найти все гласные», которую мы разбирали на семинаре. Если вас не было, решите сначала её. Если вы были на паре и решали её, то вы можете использовать здесь свой код с пары.
#
# ___

# %% [markdown]
# На семинаре мы написали программу, которая выводит все гласные в слове. При этом если в слове было несколько одинаковых гласных, то выводились все повторы (например, из `"podorozhnikami"` получалось `"oooiai"`). В этой задаче мы напишем программу, которая будет выводить гласные без повторов.
#
# Измените своё решение «Найти все гласные» таким образом, чтобы программа учитывала только первое вхождение каждой гласной. Например, если пользователь введёт строку `"podorozhnikami"`, такая программа напишет `"oia"`. (Если ни одной гласной нет, программа выведет пустую строку.)

# %% [markdown]
# Примеры правильной работы программы:
#
# ```
# > gomeopatia
# oeai
#
# > rododendron
# oe
#
# > dlinnosheee
# ioe
#
# > psst
#
# ```

# %%
vowels = "aeiou"

# ваше решение ↓ ниже этой строки

# %% [markdown]
# ### Задача 3.2. Угадайка

# %% [markdown]
# В этой задаче вам нужно написать игру, в которой компьютер будет загадывать число, а пользователь — пытаться угадать его за ограниченное количество попыток.
#
# - В начале игры компьютер загадывает и запоминает натуральное число в диапазоне от 1 до 50 включительно. (В реальной жизни программисты бы написали код, который генерирует случайное число каждый раз, но мы так ещё не умеем, поэтому просто притворимся, что оно случайное — для тестирования напишите любое подходящее число.)
# - Пользователь вводит свою догадку. (Пользователь добрый и будет вводить только натуральные числа от 1 до 50.)
#     - Если ответ пользователя верный, то компьютер печатает: `"Вы победили! Потрачено попыток: …"`, подставляя число попыток, которые потратил пользователь, и игра заканчивается.
#     - Если правильный ответ меньше, чем ответ пользователя, то компьютер печатает: `"Меньше!"`, а если правильный ответ больше — `"Больше!"`.
# - Если после очередной попытки пользователь превысил лимит попыток, то компьютер печатает: `"Вы проиграли!"`, и игра заканчивается. Если лимит ещё не превышен, пользователь вводит следуюущую догадку.
#
# Лимит попыток и загаданное число хранятся в переменных, которые определяются в начале программы. Программа должна работать корректно, даже если эти числа поменяются.

# %% [markdown]
# Допустим, что пользователю нужно угадать число `42` за четыре попытки. В таком случае, например, игра может выглядеть так:
#
# ```
# > 87
# Меньше!
# > 25
# Больше!
# > 44
# Меньше!
# > 37
# Вы проиграли!
# ```
#
# Или (если пользователю очень повезёт) так:
#
# ```
# > 2
# Больше!
# > 42
# Вы победили! Потрачено попыток: 2.
# ```

# %% [markdown]
# ___

# %% [markdown]
# _В ячейке с решением уже вписаны переменные с лимитом попыток и правильным ответом. Вы можете менять значения этих переменных, чтобы тестировать программу. (А ещё можете поменять названия переменных, если хотите — эти названия просто для примера.)_

# %%
limit = 4           # максимальное количество попыток
correct = 42        # правильный ответ

# ваше решение ↓ ниже этой строки

# %% [markdown]
# ### Задача 3.3. Ни-у-э

# %% [markdown]
# В этой задаче мы снова обратимся к языку ниуэ. Вспомним, что в ниуэ очень простая слоговая структура — все слоги представляют из себя либо сочетание «согласный + гласный», либо просто «гласный» (без начального согласного). Все остальные виды слогов в ниуэ невозможны. Вам предстоит написать программу, которая делит ниуэанское слово на слоги, а если такого слова в ниуэ быть не может, ругается на это пользователю.
#
# - Пользователь вводит слово, в котором может быть любое ненулевое число букв и слогов. (Пользователь добрый и будет вводить только слова, состоящие из латинских букв.)
# - Программа делит слово на слоги согласно правилам слоговой структуры ниуэ и печатает все слоги через пробел (в конце может остаться «лишний» пробел, это не страшно).
# - Если программа определяет, что в языке ниуэ не может быть такого слова (и разделить его на слоги по правилам слоговой структуры ниуэ не получится), то вместо вывода слогов она пишет пользователю: `"Ошибка!"`.

# %% [markdown]
# Примеры:
#
# ```
# > niue
# ni u e
#
# > kalahimu
# ka la hi mu
#
# > moskva
# Ошибка!
# ```

# %%
vowels = "aeiou"

# ваше решение ↓ ниже этой строки

# %% [markdown]
# Решение можно протестировать на этих реальных словах языка ниуэ:
# - *kalahimu* ‘крабик’
# - *tautolu* ‘мы’
# - *teau* ‘тысяча’
# - *maaga* ‘деревня’
