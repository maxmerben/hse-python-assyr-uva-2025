# %% [markdown]
# # Дополнительные задачи №15

# %% [markdown]
# ### Задача 15.1 Два грамма

# %% [markdown]
# В этом задании вам нужно написать функцию, в которую можно будет подать текст и какое-нибудь слово — а она выделит самые частотные биграммы из текста с этим словом. Таким образом можно будет, например, узнать про любое существительное, какие прилагательные встречаются с ним чаще всего. ([Можно посмотреть](https://ruscorpora.ru/results?search=), как подобный функционал реализован в Национальном корпусе русского языка.)
#
# Функция должна:
# - Принимать на вход следующие аргументы:
#     - Строку — русскоязычный текст, в котором нужно искать слово
#     - Слово, которое нужно искать в тексте (будем считать, что оно подаётся в начальной форме)
#     - Число $N$ биграмм с этим словом, которое нужно вывести
# - Проводить предварительную обработку текста (привести текст к одному регистру, токенизировать, очистить от стоп-слов и знаков препинания, лемматизировать)
# - Возвращать $N$ самых частотных биграмм текста, в которых есть искомое слово (и к каждой биграмме — число её вхождений)

# %% [markdown]
# Тестировать функцию я вам предлагаю на материале книги «Маленький принц» Антуана де Сент-Экзюпери (**[ссылка](https://github.com/maxmerben/hse-python-assyr-uva-2025/blob/main/other/sem15-little_prince.txt)**). Например, если попросить такую функцию найти в тексте «Маленького принца» пять самых частотных биграмм со словом «планета», она должна выдать что-то вроде:
#
# ```
# [(('мой', 'планета'), 6),
#  (('планета', 'жить'), 5),
#  (('планета', 'маленький'), 4),
#  (('другой', 'планета'), 3),
#  (('планета', 'который'), 3)]
# ```

# %%
# ваше решение

# %% [markdown]
# ### Задача 15.2 Русский как иностранный

# %% [markdown]
# В этом задании вам предстоит написать функцию, которая сможет сделать из любого русскоязычного текста учебный материал для изучающих русский как иностранный — с помощью такого материала студент:ки будут учиться склонять прилагательные по падежам.
#
# Функция должна:
# - Принимать на вход строку — текст, в котором нужно заменить все прилагательные
# - Искать в тексте прилагательные и заменять каждое прилагательное на соответствующую начальную форму следующим образом: `"я увидел маленького принца"` → `"я увидел ____ (маленький) принца"`
#     - (Подсказка: тег для прилагательного в `pymorphy3` — `"ADJF"`)
# - Возвращать строку — изменённый текст

# %% [markdown]
# Ниже — отрывок из «Маленького принца», на котором вы можете тестировать своё решение, и ожидаемый результат:

# %%
text = """Если поглядеть со стороны, это было великолепное зрелище. Движения этой армии подчинялись 
точнейшему ритму, совсем как в балете. Первыми выступали фонарщики Новой Зеландии и Австралии. 
Засветив свои огни, они отправлялись спать. За ними наступал черед фонарщиков Китая. 
Исполнив свой танец, они тоже скрывались за кулисами. Потом приходил черед фонарщиков в России и в Индии. 
Потом — в Африке и Европе. Затем в Южной Америке, затем в Северной Америке. И никогда они не ошибались, 
никто не выходил на сцену не вовремя. Да, это было блистательно."""

expected = """Если поглядеть со стороны, это было ____ (великолепный) зрелище. Движения ____ (этот) армии подчинялись 
____ (точный) ритму, совсем как в балете. ____ (первый) выступали фонарщики ____ (новый) Зеландии и Австралии. 
Засветив ____ (свой) огни, они отправлялись спать. За ними наступал черед фонарщиков Китая. 
Исполнив ____ (свой) танец, они тоже скрывались за кулисами. Потом приходил черед фонарщиков в России и в Индии. 
Потом — в Африке и Европе. Затем в ____ (южный) Америке, затем в ____ (северный) Америке. И никогда они не ошибались, 
никто не выходил на сцену не вовремя. Да, это было блистательно."""

# %%
# ваше решение
