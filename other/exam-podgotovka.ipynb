# %% [markdown]
# ## B04

# %%
kofe = set(input().split())
chay = set(input().split())
bol25 = set(input().split())
# Out:
#  Рита Лиза Марина Кирилл Катя Влад
#  Настя Влад Марина Ира Кирилл
#  Кирилл Лиза Ира Настя Максим

# %%
print(" ".join(sorted((kofe ^ chay) - bol25)))
# Out:
# Катя Рита

# %%
print(*sorted((kofe ^ chay) - bol25))
# Out:
# Катя Рита

# %% [markdown]
# ## A05

# %%
spisok = []
while True:
    stroka = input()
    if stroka == "КОНЕЦ":
        break
    name, number = stroka.split(", ")
    number = int(number)
    if number > 500:
        spisok.append(name)

print(sorted(spisok))

# %% [markdown]
# ## A06

# %%
"хлеб: 200, яблоки: 120, молоко: 150, макароны: 300"
# Out:
# 'хлеб: 200, яблоки: 120, молоко: 150, макароны: 300'

# %%
data = input().split(", ")
# Out:
#  хлеб: 200, яблоки: 120, молоко: 150, макароны: 300

# %%
data
# Out:
# ['хлеб: 200', 'яблоки: 120', 'молоко: 150', 'макароны: 300']

# %%
result = []
for s in data:
    product, price = s.split(": ")
    skolko = 500 // int(price)
    result.append(skolko)
print(*result, sep=", ")

max_value = max(result)
index_max_value = result.index(max_value)
print(data[index_max_value])
# Out:
# 2, 4, 3, 1
# яблоки: 120

# %% [markdown]
# ### B02

# %%
fav_desserts = {
    'Миша' : ['Тирамису', 'Панна котта', 'Безе'],
    'Ира' : ['Пишмание', 'Конфитюр', 'Пудинг'],
    'Кристина' : ['Чизкейк', 'Шербет', 'Марципан']
}

for name, desserts in fav_desserts.items():
    print(name, desserts[0], sep = ', ')
# Out:
# Миша, Тирамису
# Ира, Пишмание
# Кристина, Чизкейк

# %% [markdown]
# ### C01

# %%
with open("menu.csv", "r", encoding="utf-8") as menu:
    menu = menu.read()
menu = menu.split("\n")
price = int(input())

for stroka in menu:
    stroka_spisok = stroka.split(",")
    bludo_price = int(stroka_spisok[2])
    if bludo_price <= price:
        print(stroka)
# Out:
#  500
# омлет классический,370,390,120
# паста пенне,420,450,320
# сочный бифштекс,430,320,380
# пельмени,430,460,260
# картофель фри,380,430,420
# том ям,230,270,430
